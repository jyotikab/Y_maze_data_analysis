# %%
import pandas as pd
import numpy as np
import pylab as pl
import scipy.io as sio
import seaborn as sns
import statsmodels.api as sm
import funcs as func
import matplotlib.pyplot as plt
import sys
import pdb
import glob
import pickle
import dill

import sys
sys.path.append('/home/jyotika/Utils/hddm/')

import hddm

data_dir = "./Data/Y_maze/Decision_times/"
data_target_dir = "./Data/processed_data/Y_maze/"
figure_dir = "./Figures/Y_maze/"

plt.rcParams["figure.facecolor"] = "w"

# %%
all_conflicts = pd.read_csv(data_target_dir+"all_experiments_df_with_DTs.csv")

# %%
n_samples = 1000
n_burn = 500

# %%
def estimate_regression_model(model_specification, model_name, data, model_objects,
                              n_samples=n_samples, n_burn=n_burn, accuracy_coding=True, convergence_iteration=None):

    if accuracy_coding:
        if "z_" in model_name:
            reg_model = hddm.HDDMRegressor(data=data, models=model_specification, bias=False, group_only_regressors=True, p_outlier=0.05,include='z') # accuracy coded
        else:
            reg_model = hddm.HDDMRegressor(data=data, models=model_specification, bias=False, group_only_regressors=True, p_outlier=0.05) # accuracy coded
        reg_model.find_starting_values()
        reg_model.sample(n_samples, burn=n_burn, dbname=model_name, db='pickle')
#     else:
#         reg_model = hddm.HDDMRegressor(data=data, models=model_specification, bias=True, group_only_regressors=True, p_outlier=0.05) # stim coded
#         reg_model.find_starting_values()
#         reg_model.sample(n_samples, burn=n_burn, dbname=model_name, db='pickle')

    if convergence_iteration is None:
        model_objects[model_name] = reg_model
    else:
        model_objects[model_name + '_' + '_iter' + str(convergence_iteration)] = reg_model

# %%
def generate_trialwise_estimates(behavioral_features, av_beta_intercept_df):
    n = len(behavioral_features)
    ind0 = np.where(behavioral_features["response"]==0.0)[0]
    ind1 = np.where(behavioral_features["response"]==1.0)[0]
    
#     v_mean_intercept0 = av_beta_intercept_df.v_Intercept.mean()
#     v_mean_intercept1 = av_beta_intercept_df["v_C(response)[T.1.0]"].mean()
    
    a_mean_intercept0 = av_beta_intercept_df.a_Intercept.mean()
    a_mean_intercept1 = av_beta_intercept_df["a_C(response)[T.1.0]"].mean()
    
    
    #a_mean_intercept = av_beta_intercept_df.a_Intercept.mean()
    
    #rt_mean_beta_response0 = av_beta_intercept_df["v_rt:C(response)[0.0]"].mean()
#     rt_mean_beta = av_beta_intercept_df["v_rt"].mean()
    rt_mean_beta1 = av_beta_intercept_df["a_rt"].mean()
    
    #accuracy_mean_beta = av_beta_intercept_df.v_accuracy.mean()
#     v_jittered_intercept0 = av_beta_intercept_df.v_Intercept.sample(n).reset_index(drop=True)
#     v_jittered_intercept1 = av_beta_intercept_df["v_C(response)[T.1.0]"].sample(n).reset_index(drop=True)
    
    a_jittered_intercept0 = av_beta_intercept_df.a_Intercept.sample(n).reset_index(drop=True)
    a_jittered_intercept1 = av_beta_intercept_df["a_C(response)[T.1.0]"].sample(n).reset_index(drop=True)
    
    
#     rt_jittered_beta_response0 =  av_beta_intercept_df["v_rt:C(response)[0.0]"].sample(n).reset_index(drop=True) 
#     rt_jittered_beta_response1 =  av_beta_intercept_df["v_rt:C(response)[1.0]"].sample(n).reset_index(drop=True) 
#     rt_jittered_beta =  av_beta_intercept_df["v_rt"].sample(n).reset_index(drop=True) 
    rt_jittered_beta1 =  av_beta_intercept_df["a_rt"].sample(n).reset_index(drop=True) 
        
    print("v_jittered_intercept0",v_jittered_intercept0)
    print("rt_jittered_beta",rt_jittered_beta)
    
    
#     print("rt_jittered_beta0",rt_jittered_beta_response0)
#     print("rt_jittered_beta1",rt_jittered_beta_response1)
    
    rt = behavioral_features.rt; #accuracy = behavioral_features.accuracy

    
#     v_trialwise_estimate = [v_mean_intercept0 + rt_mean_beta * np.array(rt)[i] if x ==0 else v_mean_intercept1 + rt_mean_beta * np.array(rt)[i]    for i,x in enumerate(behavioral_features.response)]
    
#     v_trialwise_estimate_jittered = [np.array(v_jittered_intercept0)[i] + np.array(rt_jittered_beta)[i] * np.array(rt)[i] if x == 0 else np.array(v_jittered_intercept1)[i] + np.array(rt_jittered_beta)[i] * np.array(rt)[i]  for i,x in enumerate(behavioral_features.response)]

    a_trialwise_estimate = [a_mean_intercept0 + rt_mean_beta1 * np.array(rt)[i] if x ==0 else a_mean_intercept1 + rt_mean_beta1 * np.array(rt)[i]    for i,x in enumerate(behavioral_features.response)]
    #a_trialwise_estimate_jittered = a_jittered_intercept + aCPP_jittered_beta * cpp
    a_trialwise_estimate_jittered = [np.array(a_jittered_intercept0)[i] + np.array(rt_jittered_beta1)[i] * np.array(rt)[i] if x == 0 else np.array(a_jittered_intercept1)[i] + np.array(rt_jittered_beta1)[i] * np.array(rt)[i]  for i,x in enumerate(behavioral_features.response)]

#     behavioral_features['v_est'] = v_trialwise_estimate
#     behavioral_features['v_est_jittered'] = v_trialwise_estimate_jittered
#     behavioral_features['slope(v_vs_rt)'] = rt_mean_beta

    behavioral_features['a_est'] = a_trialwise_estimate
    behavioral_features['a_est_jittered'] = a_trialwise_estimate_jittered
    behavioral_features['slope(a_vs_rt)'] = rt_mean_beta1
    
    
#     behavioral_features['v_jittered_intercept0'] = v_jittered_intercept0
#     behavioral_features['v_jittered_intercept1'] = v_jittered_intercept1
    
    return behavioral_features

# %%
model_specifications = [('v~C(volatility)'),
                        ('v~ rt + C(response)','a~C(conflict)'),
                        ('v~ rt + C(response)','a~C(volatility)'),
                        ('v~ rt + C(response)','a~C(volatility) + C(conflict)'),
                        ('v~ rt + C(response) + C(volatility) + C(conflict)'),
                        ('v~ rt + C(volatility) + C(conflict)','a~C(response)'),
                        ('v~ rt + C(volatility)','a~C(conflict)')
                        
                        
                        ]
model_names = ['v_volatility' ,'v_rt_response_a_conflict', 'v_rt_a_volatility', 'v_rt_a_volatility_conflict','v_rt_volatility_conflict','v_rt_volatility_conflict_a_response','v_rt_volatility_a_conflict']

model_inputs = dict(zip(model_names, model_specifications))

print(model_inputs)
# Out:
# {'v_volatility': 'v~C(volatility)', 'v_rt_response_a_conflict': ('v~ rt + C(response)', 'a~C(conflict)'), 'v_rt_a_volatility': ('v~ rt + C(response)', 'a~C(volatility)'), 'v_rt_a_volatility_conflict': ('v~ rt + C(response)', 'a~C(volatility) + C(conflict)'), 'v_rt_volatility_conflict': 'v~ rt + C(response) + C(volatility) + C(conflict)', 'v_rt_volatility_conflict_a_response': ('v~ rt + C(volatility) + C(conflict)', 'a~C(response)'), 'v_rt_volatility_a_conflict': ('v~ rt + C(volatility)', 'a~C(conflict)')}

# %%
model_dicts = dict()
models = dict()

model_comparison = pd.DataFrame()

model_objects = dict()
    
hddm_data = all_conflicts.copy()
hddm_data["RT(ms)"] = hddm_data["RT(ms)"]/1000.
hddm_data = hddm_data.rename(columns={'optimal_action':'response','RT(ms)':'rt'})
    
for model_name, model_specification in model_inputs.items():
    estimate_regression_model(model_specification, model_name,hddm_data, model_objects)
    model_objects['model_name'] = model_name
    model_objects['dic'] = model_objects[model_name].dic
        
    temp = pd.DataFrame()
    temp = model_objects[model_name].get_traces()
    temp["model_name"] = model_name
    temp['dic'] = model_objects[model_name].dic
#     temp["conflict + volatility"] = grp[0]
    model_comparison = model_comparison.append(temp)
        
    print('model sampling complete')    
    print("dic",model_objects[model_name].dic)
# Out:
# No model attribute --> setting up standard HDDM
# Set model to ddm
# Reg Model:
# {'outcome': 'v', 'model': 'C(volatility)', 'params': ['v_Intercept', 'v_C(volatility)[T.Low]'], 'link_func': <function HDDMRegressor.__init__.<locals>.<lambda> at 0x7fa3359f2430>}
# Uses Identity Link
# -52800.22686074881
# -52800.176235872896
#  [-----------------100%-----------------] 1001 of 1000 complete in 731.9 secmodel sampling complete
# dic 105592.23387969828
# No model attribute --> setting up standard HDDM
# Set model to ddm
# Reg Model:
# {'outcome': 'v', 'model': ' rt + C(response)', 'params': ['v_Intercept', 'v_C(response)[T.1.0]', 'v_rt'], 'link_func': <function HDDMRegressor.__init__.<locals>.<lambda> at 0x7fa33531c820>}
# Uses Identity Link
# Reg Model:
# {'outcome': 'a', 'model': 'C(conflict)', 'params': ['a_Intercept', 'a_C(conflict)[T.Low]', 'a_C(conflict)[T.No]'], 'link_func': <function HDDMRegressor.__init__.<locals>.<lambda> at 0x7fa335850940>}
# Uses Identity Link
# -13286.841825095684
# -13286.840377530169
#  [-----------------100%-----------------] 1001 of 1000 complete in 1896.3 secmodel sampling complete
# dic 26492.628709955523
# No model attribute --> setting up standard HDDM
# Set model to ddm
# Reg Model:
# {'outcome': 'v', 'model': ' rt + C(response)', 'params': ['v_Intercept', 'v_C(response)[T.1.0]', 'v_rt'], 'link_func': <function HDDMRegressor.__init__.<locals>.<lambda> at 0x7fa335b3fee0>}
# Uses Identity Link
# Reg Model:
# {'outcome': 'a', 'model': 'C(volatility)', 'params': ['a_Intercept', 'a_C(volatility)[T.Low]'], 'link_func': <function HDDMRegressor.__init__.<locals>.<lambda> at 0x7fa335b3ff70>}
# Uses Identity Link
# -12826.38635107783
# -12826.361674150745
#  [-----------------100%-----------------] 1001 of 1000 complete in 1558.7 secmodel sampling complete
# dic 25577.431413663424
# No model attribute --> setting up standard HDDM
# Set model to ddm
# Reg Model:
# {'outcome': 'v', 'model': ' rt + C(response)', 'params': ['v_Intercept', 'v_C(response)[T.1.0]', 'v_rt'], 'link_func': <function HDDMRegressor.__init__.<locals>.<lambda> at 0x7fa335b3fb80>}
# Uses Identity Link
# Reg Model:
# {'outcome': 'a', 'model': 'C(volatility) + C(conflict)', 'params': ['a_Intercept', 'a_C(volatility)[T.Low]', 'a_C(conflict)[T.Low]', 'a_C(conflict)[T.No]'], 'link_func': <function HDDMRegressor.__init__.<locals>.<lambda> at 0x7fa332a0cd30>}
# Uses Identity Link
# -12741.074604287429
# -12741.058100179658
#  [-----------------100%-----------------] 1001 of 1000 complete in 1332.4 secmodel sampling complete
# dic 25396.986743014444
# No model attribute --> setting up standard HDDM
# Set model to ddm
# Reg Model:
# {'outcome': 'v', 'model': ' rt + C(response) + C(volatility) + C(conflict)', 'params': ['v_Intercept', 'v_C(response)[T.1.0]', 'v_C(volatility)[T.Low]', 'v_C(conflict)[T.Low]', 'v_C(conflict)[T.No]', 'v_rt'], 'link_func': <function HDDMRegressor.__init__.<locals>.<lambda> at 0x7fa33577c3a0>}
# Uses Identity Link
# -14882.669233552486
# -13361.426224230134
#  [-----------------100%-----------------] 1001 of 1000 complete in 1153.5 secmodel sampling complete
# dic 26636.788676754553
# No model attribute --> setting up standard HDDM
# Set model to ddm
# Reg Model:
# {'outcome': 'v', 'model': ' rt + C(volatility) + C(conflict)', 'params': ['v_Intercept', 'v_C(volatility)[T.Low]', 'v_C(conflict)[T.Low]', 'v_C(conflict)[T.No]', 'v_rt'], 'link_func': <function HDDMRegressor.__init__.<locals>.<lambda> at 0x7fa335885280>}
# Uses Identity Link
# Reg Model:
# {'outcome': 'a', 'model': 'C(response)', 'params': ['a_Intercept', 'a_C(response)[T.1.0]'], 'link_func': <function HDDMRegressor.__init__.<locals>.<lambda> at 0x7fa335360670>}
# Uses Identity Link
# -47558.259687977414
# -47557.29955879597
#  [-----------------100%-----------------] 1001 of 1000 complete in 1312.8 secmodel sampling complete
# dic 95082.63080186996
# No model attribute --> setting up standard HDDM
# Set model to ddm
# Reg Model:
# {'outcome': 'v', 'model': ' rt + C(volatility)', 'params': ['v_Intercept', 'v_C(volatility)[T.Low]', 'v_rt'], 'link_func': <function HDDMRegressor.__init__.<locals>.<lambda> at 0x7fa335360550>}
# Uses Identity Link
# Reg Model:
# {'outcome': 'a', 'model': 'C(conflict)', 'params': ['a_Intercept', 'a_C(conflict)[T.Low]', 'a_C(conflict)[T.No]'], 'link_func': <function HDDMRegressor.__init__.<locals>.<lambda> at 0x7fa33703c9d0>}
# Uses Identity Link
# -47612.21813598899
# -47611.66111882115
#  [-----------------100%-----------------] 1001 of 1000 complete in 1157.4 secmodel sampling complete
# dic 95197.22238606041

# %%
# model_name = 'v_rt_volatility_conflict_a_response'
# model_specification = ('v~ rt + C(volatility) + C(conflict)','a~C(response)')

# estimate_regression_model(model_specification, model_name,hddm_data, model_objects)
# model_objects['model_name'] = model_name
# model_objects['dic'] = model_objects[model_name].dic
        
# temp = pd.DataFrame()
# temp = model_objects[model_name].get_traces()
# temp["model_name"] = model_name
# temp['dic'] = model_objects[model_name].dic
# model_comparison = model_comparison.append(temp)
        
# print('model sampling complete')    
# print("dic",model_objects[model_name].dic)

# %%
model_objects[model_name].dic
# Out:
# 95196.98258954885

# %%
# def z_link_func(x, data):
#     stim = (np.asarray(dmatrix('0 + C(s, [[0], [1]])',
#                               {'s': data.stimulus.loc[x.index]},return_type='dataframe'))
#     )
#     # Apply z = (1 - x) to flip them along 0.5
#     z_flip = np.subtract(stim, x.to_frame())
#     # The above inverts those values we do not want to flip,
#     # so invert them back
#     z_flip[stim == 0] *= -1
#     return z_flip

# %%
model_comparison.to_csv(data_target_dir+"model_comparison_full_data.csv")

# %%
model_comparison
# Out:
#             a         t  v_Intercept  v_C(volatility)[T.Low]  \
# 0    1.696837  0.062600     0.351223               -0.093535
# 1    1.691711  0.061922     0.327779               -0.069029
# 2    1.693863  0.063278     0.326067               -0.054656
# 3    1.690881  0.063539     0.314522               -0.034640
# 4    1.697066  0.060060     0.312312               -0.041001
# ..        ...       ...          ...                     ...
# 495       NaN  0.057433     0.206019               -0.084851
# 496       NaN  0.056624     0.200466               -0.076362
# 497       NaN  0.057662     0.200235               -0.068190
# 498       NaN  0.058325     0.196781               -0.073911
# 499       NaN  0.058527     0.202924               -0.080524
#
#                      model_name            dic  v_C(response)[T.1.0]  \
# 0                  v_volatility  105592.233880                   NaN
# 1                  v_volatility  105592.233880                   NaN
# 2                  v_volatility  105592.233880                   NaN
# 3                  v_volatility  105592.233880                   NaN
# 4                  v_volatility  105592.233880                   NaN
# ..                          ...            ...                   ...
# 495  v_rt_volatility_a_conflict   95197.222386                   NaN
# 496  v_rt_volatility_a_conflict   95197.222386                   NaN
# 497  v_rt_volatility_a_conflict   95197.222386                   NaN
# 498  v_rt_volatility_a_conflict   95197.222386                   NaN
# 499  v_rt_volatility_a_conflict   95197.222386                   NaN
#
#          v_rt  a_Intercept  a_C(conflict)[T.Low]  a_C(conflict)[T.No]  \
# 0         NaN          NaN                   NaN                  NaN
# 1         NaN          NaN                   NaN                  NaN
# 2         NaN          NaN                   NaN                  NaN
# 3         NaN          NaN                   NaN                  NaN
# 4         NaN          NaN                   NaN                  NaN
# ..        ...          ...                   ...                  ...
# 495  0.670697     1.706793              0.058628             0.062183
# 496  0.668727     1.708147              0.066547             0.075916
# 497  0.667669     1.703891              0.068499             0.069658
# 498  0.675322     1.687344              0.066890             0.078984
# 499  0.666271     1.691949              0.080992             0.081009
#
#      a_C(volatility)[T.Low]  v_C(conflict)[T.Low]  v_C(conflict)[T.No]  \
# 0                       NaN                   NaN                  NaN
# 1                       NaN                   NaN                  NaN
# 2                       NaN                   NaN                  NaN
# 3                       NaN                   NaN                  NaN
# 4                       NaN                   NaN                  NaN
# ..                      ...                   ...                  ...
# 495                     NaN                   NaN                  NaN
# 496                     NaN                   NaN                  NaN
# 497                     NaN                   NaN                  NaN
# 498                     NaN                   NaN                  NaN
# 499                     NaN                   NaN                  NaN
#
#      a_C(response)[T.1.0]
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ..                    ...
# 495                   NaN
# 496                   NaN
# 497                   NaN
# 498                   NaN
# 499                   NaN
#
# [3500 rows x 15 columns]

# %%
# for grp in model_comparison.loc[model_comparison["conflict + volatility"]=="No - High"].groupby('model_name'):
#     print(grp[0])
#     print(grp[1].dic)

# %%
g1 = sns.catplot(x="model_name",y="dic",data=model_comparison,kind='bar')

for ax in g1.axes[0]:
    xticklabels = [model_inputs[x.get_text()]   for x in ax.get_xticklabels()]
    print(xticklabels)
    ax.set_xticklabels(xticklabels,rotation=45,fontweight='bold',fontsize=10,ha='right')
    #ax.set_ylim(-500,20000)
g1.savefig(figure_dir+"Model_comparison_dic_full_data.png")
# Out:
# ['v~C(volatility)', ('v~ rt + C(response)', 'a~C(conflict)'), ('v~ rt + C(response)', 'a~C(volatility)'), ('v~ rt + C(response)', 'a~C(volatility) + C(conflict)'), 'v~ rt + C(response) + C(volatility) + C(conflict)', ('v~ rt + C(volatility) + C(conflict)', 'a~C(response)'), ('v~ rt + C(volatility)', 'a~C(conflict)')]

# %%
# hddm_data = grp[1].iloc[:100].copy()
# hddm_data["RT(ms)"] = hddm_data["RT(ms)"]/1000.
# hddm_data = hddm_data.rename(columns={'optimal_action':'response','RT(ms)':'rt'})
        
# m = hddm.HDDMRegressor(hddm_data,('v ~ rt','a ~rt',{'model':'z ~ C(response)','link_func': lambda x: x}),p_outlier=0.05,include='z')
# m.find_starting_values()
# m.sample(100,burn=10)
# Out:
# No model attribute --> setting up standard HDDM
# Set model to ddm
# Reg Model:
# {'outcome': 'v', 'model': ' rt', 'params': ['v_Intercept', 'v_rt'], 'link_func': <function HDDMRegressor.__init__.<locals>.<lambda> at 0x7fbce7c46d30>}
# Uses Identity Link
# Reg Model:
# {'outcome': 'a', 'model': 'rt', 'params': ['a_Intercept', 'a_rt'], 'link_func': <function HDDMRegressor.__init__.<locals>.<lambda> at 0x7fbce7c46c10>}
# Uses Identity Link
# Reg Model:
# {'outcome': 'z', 'model': ' C(response)', 'params': ['z_Intercept', 'z_C(response)[T.1.0]'], 'link_func': <function <lambda> at 0x7fbce7c46dc0>}
# Uses Identity Link
# -49.45525966185132
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_78627/2051633453.py in <module>
#       4
#       5 m = hddm.HDDMRegressor(hddm_data,('v ~ rt','a ~rt',{'model':'z ~ C(response)','link_func': lambda x: x}),p_outlier=0.05,include='z')
# ----> 6 m.find_starting_values()
#       7 m.sample(100,burn=10)
#
# ~/Utils/envs/for_hddm_python3.10/lib/python3.8/site-packages/kabuki/hierarchical.py in find_starting_values(self, *args, **kwargs)
#     976             self.approximate_map(*args, **kwargs)
#     977         else:
# --> 978             self.map(*args, **kwargs)
#     979
#     980     def _partial_optimize(self, optimize_nodes, evaluate_nodes, fall_to_simplex=True, minimizer='Powell', use_basin=False, debug=False, minimizer_kwargs=None, basin_kwargs=None):
#
# ~/Utils/envs/for_hddm_python3.10/lib/python3.8/site-packages/kabuki/hierarchical.py in map(self, runs, warn_crit, method, **kwargs)
#     503             self.mc = pm.MAP(self.nodes_db.node)
#     504             if i != 0:
# --> 505                 self.draw_from_prior()
#     506
#     507             self.mc.fit(method, **kwargs)
#
# ~/Utils/envs/for_hddm_python3.10/lib/python3.8/site-packages/kabuki/hierarchical.py in draw_from_prior(self, update)
#     464         if not update:
#     465             # restore original values
# --> 466             self.set_values(values)
#     467
#     468         return draw
#
# ~/Utils/envs/for_hddm_python3.10/lib/python3.8/site-packages/kabuki/hierarchical.py in set_values(self, new_values)
#     965         """
#     966         for (name, value) in new_values.items():
# --> 967             self.nodes_db.loc[name]['node'].set_value(value)
#     968
#     969     def find_starting_values(self, *args, **kwargs):
#
# ~/Utils/envs/for_hddm_python3.10/lib/python3.8/site-packages/pymc/PyMCObjects.py in set_value(self, value)
#     474
#     475     def set_value(self, value):
# --> 476         raise AttributeError(
#     477             'Deterministic ' +
#     478             self.__name__ +
#
# AttributeError: Deterministic z_Intercept's value cannot be set.

# %%
hddm_data['rt'].min()
# Out:
# 0.11

# %%
# m.find_starting_values()
# m.sample(10000, burn=1000,dbname='v_rt',db='pickle')

# %%
# hddm_data = generate_trialwise_estimates(hddm_data, m.get_traces())

# %%
# models = dict()
# model_dicts[grp[0]] = hddm_data.copy()
# models[grp[0]+"_model"] = m

# %%
pickle.dump(model_dicts,open(data_target_dir+"model_dict_DDM_vs_behavioral_features_a.pickle","wb"))

# %%
dill.dump(models,open(data_target_dir+"models_DDM_vs_behavioral_features.pickle_a.pickle","wb"))

# %%
model_dicts = pickle.load(open(data_target_dir+"model_dict_DDM_vs_behavioral_features_a.pickle","rb"))

# %%
model_dicts['High - High']
# Out:
#        Unnamed: 0  level_0  index conflict condition volatility  event_marker  \
# 6013         6013        0      0     High   Control       High             8
# 6014         6014        1      1     High   Control       High             8
# 6015         6015        2      2     High   Control       High             8
# 6016         6016        3      3     High   Control       High             8
# 6017         6017        4      4     High   Control       High             1
# ...           ...      ...    ...      ...       ...        ...           ...
# 11564       11564     5551   8341     High   Control       High             8
# 11565       11565     5552   8342     High   Control       High             8
# 11566       11566     5553   8343     High   Control       High             8
# 11567       11567     5554   8344     High   Control       High             8
# 11568       11568     5555   8345     High   Control       High             8
#
#       block reward_probability trial_length_range  ...  chosen_action  \
# 6013   left              25-75              10-20  ...          right
# 6014   left              25-75              10-20  ...          right
# 6015   left              25-75              10-20  ...          right
# 6016   left              25-75              10-20  ...          right
# 6017   left              25-75              10-20  ...           left
# ...     ...                ...                ...  ...            ...
# 11564  left              25-75              10-20  ...          right
# 11565  left              25-75              10-20  ...          right
# 11566  left              25-75              10-20  ...          right
# 11567  left              25-75              10-20  ...          right
# 11568  left              25-75              10-20  ...          right
#
#          rewarded  response     rt conflict + volatility      v_est  \
# 6013   unrewarded       0.0  0.299           High - High  -7.666196
# 6014   unrewarded       0.0  0.413           High - High  -8.109206
# 6015   unrewarded       0.0  0.942           High - High -10.164929
# 6016   unrewarded       0.0  0.417           High - High  -8.124751
# 6017     rewarded       1.0  1.250           High - High   8.123571
# ...           ...       ...    ...                   ...        ...
# 11564  unrewarded       0.0  1.933           High - High -14.016010
# 11565  unrewarded       0.0  0.450           High - High  -8.252990
# 11566  unrewarded       0.0  1.122           High - High -10.864419
# 11567  unrewarded       0.0  0.504           High - High  -8.462837
# 11568  unrewarded       0.0  1.235           High - High -11.303544
#
#        v_est_jittered slope(v_vs_rt)  v_jittered_intercept0  \
# 6013        -7.708899      -3.886055                    NaN
# 6014        -8.173340      -3.886055                    NaN
# 6015       -10.074255      -3.886055                    NaN
# 6016        -8.106254      -3.886055                    NaN
# 6017         8.066603      -3.886055                    NaN
# ...               ...            ...                    ...
# 11564      -13.869722      -3.886055                    NaN
# 11565       -8.192402      -3.886055                    NaN
# 11566      -10.851658      -3.886055                    NaN
# 11567       -8.511654      -3.886055                    NaN
# 11568      -11.592457      -3.886055                    NaN
#
#        v_jittered_intercept1
# 6013                     NaN
# 6014                     NaN
# 6015                     NaN
# 6016                     NaN
# 6017                     NaN
# ...                      ...
# 11564                    NaN
# 11565                    NaN
# 11566                    NaN
# 11567                    NaN
# 11568                    NaN
#
# [5556 rows x 23 columns]

# %%
all_rts_vs_drift = pd.DataFrame()

for k in model_dicts.keys():
    print(k)
    if "model" in k:
        continue
    df = model_dicts[k]
    all_rts_vs_drift = all_rts_vs_drift.append(df)
all_rts_vs_drift.to_csv(data_target_dir+"all_rts_vs_drift_a.csv")

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_78627/1396537375.py in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
g1 = sns.lmplot(x="rt",y="v_est_jittered",data=all_rts_vs_drift,hue="response",col="conflict + volatility",col_wrap=3,sharey=False,sharex=False)
g1.savefig(figure_dir+"vest_jittered_vs_rt_all_a.png")
# Out:
# /home/jyotika/.local/lib/python3.8/site-packages/seaborn/regression.py:592: UserWarning: sharex is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)
# /home/jyotika/.local/lib/python3.8/site-packages/seaborn/regression.py:592: UserWarning: sharey is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)

# %%
g2 = sns.lmplot(x="rt",y="v_est_jittered",data=all_rts_vs_drift.loc[all_rts_vs_drift["response"]==1.0],hue="volatility",col="conflict",col_wrap=3,sharex=False,sharey=False)
g2.savefig(figure_dir+"vest_jittered_vs_rt_optimal_actions_a.png")
# Out:
# /home/jyotika/.local/lib/python3.8/site-packages/seaborn/regression.py:592: UserWarning: sharex is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)
# /home/jyotika/.local/lib/python3.8/site-packages/seaborn/regression.py:592: UserWarning: sharey is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)

# %%
g2 = sns.lmplot(x="rt",y="v_est_jittered",data=all_rts_vs_drift.loc[all_rts_vs_drift["response"]==0.0],hue="volatility",col="conflict",col_wrap=3,sharex=False,sharey=False)
g2.savefig(figure_dir+"vest_jittered_vs_rt_sub_optimal_actions_a.png")
# Out:
# /home/jyotika/.local/lib/python3.8/site-packages/seaborn/regression.py:592: UserWarning: sharex is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)
# /home/jyotika/.local/lib/python3.8/site-packages/seaborn/regression.py:592: UserWarning: sharey is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)

# %%
g3 = sns.catplot(x="conflict",y='slope(v_vs_rt)',data=all_rts_vs_drift,hue="volatility",kind='bar')
g3.savefig(figure_dir+"Slope_v_vs_rt_all_a.png")

# %%
g3 = sns.catplot(x="conflict",y='v_est_jittered',data=all_rts_vs_drift,hue="volatility",kind='point',dodge=True,order=["No","Low","High"])
g3.savefig(figure_dir+"v_est_jittered_all_a.png")

# %%
g4 = sns.catplot(x="conflict",y='rt',data=all_rts_vs_drift,hue="volatility",kind='point',dodge=True,order=["No","Low","High"])
g4.savefig(figure_dir+"reaction_times_all.png")
